# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1 = df = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")

# %%
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
cars2 = df = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")

# %%
cars2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %% [markdown]
# Thought about deleting these columns, so I before doing so I might as well check if they are completely empty.First I create alist of all columns I want to check:

# %%
columns_to_remove = ['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12','Unnamed: 13']

# %%
check_columns = cars1[columns_to_remove].isna().all()
check_columns
# Out:
# Unnamed: 9     True
# Unnamed: 10    True
# Unnamed: 11    True
# Unnamed: 12    True
# Unnamed: 13    True
# dtype: bool

# %% [markdown]
# it appears that all columns are empty .Deleting these rows :

# %%
cars1.drop(columns=columns_to_remove, inplace=True)

# %%
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %% [markdown]
# Explanation
# #### Identify and Validate Specific Columns:
#
# - The valid columns are checked for being entirely NaN.
# - The empty columns are identified and stored in columns_to_remove.
# #### Remove the Columns:
#
# - The drop method is used to remove the specified columns from the DataFrame.
# - The inplace=True parameter ensures the changes are applied directly to the DataFrame without needing to reassign it.

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           198 non-null    float64
#  1   cylinders     198 non-null    int64
#  2   displacement  198 non-null    int64
#  3   horsepower    198 non-null    object
#  4   weight        198 non-null    int64
#  5   acceleration  198 non-null    float64
#  6   model         198 non-null    int64
#  7   origin        198 non-null    int64
#  8   car           198 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.1+ KB

# %%
cars2.info()
cars2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           200 non-null    float64
#  1   cylinders     200 non-null    int64
#  2   displacement  200 non-null    int64
#  3   horsepower    200 non-null    object
#  4   weight        200 non-null    int64
#  5   acceleration  200 non-null    float64
#  6   model         200 non-null    int64
#  7   origin        200 non-null    int64
#  8   car           200 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.2+ KB
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# ...

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
result = pd.concat([cars1,cars2], ignore_index=True)

# %%
result
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 198 Entries

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 200 Entries

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    int64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Total entries after concatenation of two Dataframes

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
import numpy as np

# %% [markdown]
# To generate a random number for each row, we first need to know how many rows are in the DataFrame. This is done using result.shape[0], where shape[0] returns the number of rows.We know how many rows are in the datashape(look above) but we could also use shape[] to extract this information and use it whilst adding a new column with new random numbers as values :

# %%
num_rows = result.shape[0]

# %% [markdown]
# We want to create random integers between 15,000 and 73,000 for each row. We use numpy's randint function to generate these numbers

# %%
random_numbers = np.random.randint(15000, 73001, size= num_rows)

# %% [markdown]
# - 15000: The lower bound (inclusive).
# - 73001: The upper bound (exclusive). We use 73001 because randint does not include the upper bound, so this ensures we get numbers up to 73,000.
# - size=num_rows: The number of random integers to generate, equal to the number of rows in the DataFrame.

# %% [markdown]
# We add these random numbers as a new column named owners to the DataFrame. This is done by assigning the random_numbers array to result['owners']:

# %%
result['owners'] = random_numbers

# %%
result
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# ...
